# %%
def gcd(x,y):
    a=min(x,y)
    for i in range(a,0,-1):
        if x%i==0 and y%i==0:
            print(i)
            break

# %%
gcd(5,7)
# Out:
# 1

# %%
def si(p,t,r=12):
    return (p*r*t)/100

# %%
si(1000,5)
# Out:
# 600.0
