# %%
course=['history','math','physics','compsci']
print(course)
# Out:
# ['history', 'math', 'physics', 'compsci']

# %%
print(len(course))
# Out:
# 4

# %%
print(course[0])
# Out:
# history

# %%
print(course[-1])
# Out:
# compsci

# %%
print(course[0:2])
# Out:
# ['history', 'math']

# %%
course.insert(0,'chem')

# %%
course
# Out:
# ['chem', 'history', 'math', 'physics', 'compsci']

# %%
course2=['art','edu']

# %%
course.extend(course2)
course
# Out:
# ['chem', 'history', 'physics', 'compsci', 'art', 'edu', 'art', 'edu']

# %%
course.remove('art')
course.remove('edu')
course
# Out:
# ['chem', 'history', 'physics', 'compsci', 'edu']

# %%
course.remove('edu')
course
# Out:
# ['chem', 'history', 'physics', 'compsci']

# %%
course.pop()
# Out:
# 'compsci'

# %%
course.reverse()
course
# Out:
# ['physics', 'history', 'chem']

# %%
course.sort()
course
# Out:
# ['chem', 'history', 'physics']

# %%
nums=[2,3,4,45,5]

# %%
nums.sort()
nums
# Out:
# [2, 3, 4, 5, 45]

# %%
nums.sort(reverse=True)
nums
# Out:
# [45, 5, 4, 3, 2]

# %%
sortc=sorted(course)
sortc
# Out:
# ['chem', 'history', 'physics']

# %%
course3=['history','math','physics','compsci']

# %%
for index,c in enumerate(course3):
    print(index,c)
# Out:
# 0 history
# 1 math
# 2 physics
# 3 compsci

# %%
list1=['history', 'math', 'physics', 'compsci']
list2=list1

# %%
list1
list2
# Out:
# ['history', 'math', 'physics', 'compsci']

# %%
list1[0]='art'
print(list1)
print(list2)
# Out:
# ['art', 'math', 'physics', 'compsci']
# ['art', 'math', 'physics', 'compsci']

# %%
tuple1=('history', 'math', 'physics', 'compsci')
tuple2=tuple1

# %%
tuple1[0]='art'             #tuple are immutable
print(tuple1)
print(tuple2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 tuple1[0]='art'
#       2 print(tuple1)
#       3 print(tuple2)
#
# TypeError: 'tuple' object does not support item assignment

# %%
cs={'history', 'math', 'physics', 'compsci','math'}
cs
# Out:
# {'compsci', 'history', 'math', 'physics'}

# %%
art={'history', 'physics', 'art','design'}
art
# Out:
# {'art', 'design', 'history', 'physics'}

# %%
cs.intersection(art)
# Out:
# {'history', 'physics'}

# %%
cs.difference(art)
# Out:
# {'compsci', 'math'}

# %%
cs.union(art)
# Out:
# {'art', 'compsci', 'design', 'history', 'math', 'physics'}

# %%
c='dindondvd'
c.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 2
#       1 c='dindondvd'
# ----> 2 c.sort()
#
# AttributeError: 'str' object has no attribute 'sort'
