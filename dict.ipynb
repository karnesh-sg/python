# %%
student={'name':'jhon','age':25,'course':['math','compsci']}
student
# Out:
# {'name': 'jhon', 'age': 25, 'course': ['math', 'compsci']}

# %%
student['name']
# Out:
# 'jhon'

# %%
student.get('name')
# Out:
# 'jhon'

# %%
student['phone']='4534-3433-3443'
student
# Out:
# {'name': 'jhon',
#  'age': 25,
#  'course': ['math', 'compsci'],
#  'phone': '4534-3433-3443'}

# %%
age=student.pop('age')
student
# Out:
# {'name': 'jhon', 'course': ['math', 'compsci'], 'phone': '4534-3433-3443'}

# %%
age
# Out:
# 25

# %%
len(student)
# Out:
# 3

# %%
s={1,2,3}
type(s)
# Out:
# set

# %%
s1={'a':1,'b':2,'c':3}
type(s1)
# Out:
# dict

# %%
id={1,2,3}
age={22,23,34}

# %%
df={'id':[1,2,3],'age':[22,23,24]}
df
# Out:
# {'id': [1, 2, 3], 'age': [22, 23, 24]}

# %%
df['id']
# Out:
# [1, 2, 3]

# %%
df['location']= ['blr','pune','chennai']
df
# Out:
# {'id': [1, 2, 3], 'age': [22, 23, 24], 'location': ['blr', 'pune', 'chennai']}

# %%
df.update({'status':[1,0,0],'age':[24,32,23],'name':['rohan','ravi','nair']})
df
# Out:
# {'id': [1, 2, 3],
#  'age': [24, 32, 23],
#  'location': ['blr', 'pune', 'chennai'],
#  'status': [1, 0, 0],
#  'name': ['rohan', 'ravi', 'nair']}

# %%
df.get('name')
# Out:
# ['rohan', 'ravi', 'nair']

# %%
for i in df:
    print(i,':',df[i])
# Out:
# id : [1, 2, 3]
# age : [24, 32, 23]
# location : ['blr', 'pune', 'chennai']
# status : [1, 0, 0]
# name : ['rohan', 'ravi', 'nair']

# %%
'age' in df.keys()
# Out:
# True

# %%
'sal' in df.keys()
# Out:
# False

# %%
'1' in df.items()
# Out:
# False
