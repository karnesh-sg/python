# %%
student={'name':'jhon','age':25,'course':['math','compsci']}
student
# Out:
# {'name': 'jhon', 'age': 25, 'course': ['math', 'compsci']}

# %%
student['name']
# Out:
# 'jhon'

# %%
student.get('name')
# Out:
# 'jhon'

# %%
student['phone']='4534-3433-3443'
student
# Out:
# {'name': 'jhon',
#  'age': 25,
#  'course': ['math', 'compsci'],
#  'phone': '4534-3433-3443'}

# %%
age=student.pop('age')
student
# Out:
# {'name': 'jhon', 'course': ['math', 'compsci'], 'phone': '4534-3433-3443'}

# %%
age
# Out:
# 25

# %%
len(student)
# Out:
# 3
