# %%
e=[(1,"bipin"),(2,"Nutan"),(3,"Netan"),(4,"Naven"),(5,"ramesh")]

# %%
for i in e:
    print(i)
# Out:
# (1, 'bipin')
# (2, 'Nutan')
# (3, 'Netan')
# (4, 'Naven')
# (5, 'ramesh')

# %%
for i,j in e:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i,j in e:
    print(j)
# Out:
# bipin
# Nutan
# Netan
# Naven
# ramesh

# %%
for i,j in e:
    print(f"Roll number {i} is {j}")
# Out:
# Roll number 1 is bipin
# Roll number 2 is Nutan
# Roll number 3 is Netan
# Roll number 4 is Naven
# Roll number 5 is ramesh

# %%
e[::-1]
# Out:
# [(5, 'ramesh'), (4, 'Naven'), (3, 'Netan'), (2, 'Nutan'), (1, 'bipin')]

# %%
a=5
b=10
a,b=b,a
print(a,b)
# Out:
# 10 5

# %%
temp=a
a=b
b=temp
print(a,b)
# Out:
# 5 10

# %%
e=(2,3,4,5,6,7,8,8,6,5,6,43,3)
len(e)
# Out:
# 13

# %%
s={2,34,5,7,89,5,2,3,4,3,4,5,34,5,6,3,3}
s
# Out:
# {2, 3, 4, 5, 6, 7, 34, 89}

# %%
s.pop()
# Out:
# 2

# %%
s.pop()
# Out:
# 34

# %%
s.add(38)
s
# Out:
# {3, 4, 5, 6, 7, 38, 89}

# %%
s1={2,3,4,5}
s2={1,3,4,6,7,8}

# %%
s1.intersection(s2)
# Out:
# {3, 4}

# %%
s2.intersection(s1)
# Out:
# {3, 4}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.difference(s2)
# Out:
# {2, 5}

# %%
s2.difference(s1)
# Out:
# {1, 6, 7, 8}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 5, 6, 7, 8}

# %%
def chk_binary(a):
    s=set(str(a))
    if s<={"0","1"}:
        return "binary"
    else:
        return "not binary"

# %%
chk_binary(101100110010100)
# Out:
# 'binary'

# %%
chk_binary(324256442)
# Out:
# 'not binary'
