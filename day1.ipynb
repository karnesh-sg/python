# %%
mes="HEY THERE WELCOME TO PYTHON"
print(len(mes))
# Out:
# 27

# %%
mes[5]
# Out:
# 'H'

# %%
mes[0:7]
# Out:
# 'HEY THE'

# %%
mes[22:12:-1]
# Out:
# 'YP OT EMOC'

# %%
mes.lower()
# Out:
# 'hey there welcome to python'

# %%
print(mes.count('O'))
# Out:
# 3

# %%
mes.find('WELCOME')
# Out:
# 10

# %%
mes=mes.replace('HEY','HI')
mes
# Out:
# 'HI THERE WELCOME TO PYTHON'

# %%
if mes.islower:
    print('Hi')
# Out:
# Hi

# %%
num=3
print(type(num))
a=3.2
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>

# %%
num+=1
num
# Out:
# 6

# %%
courses=['history','physics','compsci']
courses
# Out:
# ['history', 'physics', 'compsci']

# %%
courses[2]
# Out:
# 'compsci'

# %%
courses[-1]
# Out:
# 'compsci'

# %%
courses.append('art')
courses
# Out:
# ['history', 'physics', 'compsci', 'art']

# %%
courses.insert(0,'chem')
courses
# Out:
# ['chem', 'history', 'physics', 'compsci', 'art']

# %%
courses.sort()
courses
# Out:
# ['art', 'chem', 'compsci', 'history', 'physics']

# %%
print(max(courses))
# Out:
# physics

# %%
courses.index('compsci')
# Out:
# 2

# %%
print('art' in courses)
# Out:
# True

# %%
for i in courses:
    print(i)
# Out:
# art
# chem
# compsci
# history
# physics

# %%
for i,c in enumerate(courses,start=1):
    print(i,c)
# Out:
# 1 art
# 2 chem
# 3 compsci
# 4 history
# 5 physics

# %%
coustr=', '.join(courses)
coustr
# Out:
# 'art, chem, compsci, history, physics'

# %%
courses=set(courses)
courses
# Out:
# {'art', 'chem', 'compsci', 'history', 'physics'}

# %%
name = 'Karnesh'
college = 'SSN College of Engineering'
cgpa = 8.63
year = 2024

# %%
print(f'Name:{name}, College:{college}, CGPA:{cgpa}')
# Out:
# Name:Karnesh, College:SSN College of Engineering, CGPA:8.63

# %%
sentence = '  hello from SSN '

# %%
sentence.strip(' ')
# Out:
# 'hello from SSN'

# %%
sentence.upper()
# Out:
# '  HELLO FROM SSN '

# %%
sentence.replace('hi','hello')
# Out:
# '  hello from SSN '

# %%
sentence.split(' ')
# Out:
# ['', '', 'hello', 'from', 'SSN', '']

# %%
scores = [45, 78, 23, 91, 56, 88, 34, 72]

# %%
print(max(scores),min(scores),sum(scores))
# Out:
# 91 23 487

# %%
sorted(scores,reverse=True)
# Out:
# [91, 88, 78, 72, 56, 45, 34, 23]

# %%
scores.append(25)
scores
# Out:
# [45, 78, 23, 91, 56, 88, 34, 72, 25, 25]

# %%
scores.remove(25)
scores
# Out:
# [45, 78, 23, 91, 56, 88, 34, 72]

# %%
for i,s in enumerate(scores):
    print(i+1,s)
# Out:
# 1 45
# 2 78
# 3 23
# 4 91
# 5 56
# 6 88
# 7 34
# 8 72

# %%
above_60 = [s for s in scores if s > 60]
grade = ['A' if s>=75 else 'B' if s>=60 else 'C' for s in scores]

print(above_60)
print(grade)
# Out:
# [78, 91, 88, 72]
# ['C', 'A', 'C', 'A', 'C', 'A', 'C', 'B']

# %%
nums=[1,2,3,4,5]

# %%
for i in nums:
    if i==3:
        print("FOUND")
        break
    print(i)
# Out:
# 1
# 2
# FOUND
